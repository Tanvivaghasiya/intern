# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report

# %%
#a="Restaurant_Reviews.tsv"
data=pd.read_csv("Restaurant_Reviews.tsv",sep="\t")

# %%
import random

# %%
data.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %% [markdown]
# random assign

# %%
categories = ['service', 'food', 'ambiance', 'value', 'overall']

# %%
data['Category'] = [random.choice(categories) for _ in range(len(data))]

# %%
df_labeled = pd.DataFrame(data)

# %%
df_labeled
# Out:
#                                                 Review  Liked  Category
# 0                             Wow... Loved this place.      1   service
# 1                                   Crust is not good.      0      food
# 2            Not tasty and the texture was just nasty.      0     value
# 3    Stopped by during the late May bank holiday of...      1   service
# 4    The selection on the menu was great and so wer...      1   service
# ..                                                 ...    ...       ...
# 995  I think food should have flavor and texture an...      0   service
# 996                           Appetite instantly gone.      0      food
# 997  Overall I was not impressed and would not go b...      0  ambiance
# 998  The whole experience was underwhelming, and I ...      0     value
# 999  Then, as if I hadn't wasted enough of my life ...      0      food
#
# [1000 rows x 3 columns]

# %%
X = data['Review']
y = data['Category']

# %%
vectorizer = TfidfVectorizer(stop_words='english', lowercase=True)
X_tfidf = vectorizer.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.5, random_state=12)

# %%
model =  MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     ambiance       0.25      0.17      0.20       102
#         food       0.20      0.14      0.16       102
#      overall       0.14      0.13      0.13        94
#      service       0.15      0.16      0.15        95
#        value       0.28      0.45      0.34       107
#
#     accuracy                           0.21       500
#    macro avg       0.20      0.21      0.20       500
# weighted avg       0.21      0.21      0.20       500
#
# Accuracy: 0.212

# %%
df_labeled
# Out:
#                                                 Review  Liked  Category
# 0                             Wow... Loved this place.      1   service
# 1                                   Crust is not good.      0      food
# 2            Not tasty and the texture was just nasty.      0     value
# 3    Stopped by during the late May bank holiday of...      1   service
# 4    The selection on the menu was great and so wer...      1   service
# ..                                                 ...    ...       ...
# 995  I think food should have flavor and texture an...      0   service
# 996                           Appetite instantly gone.      0      food
# 997  Overall I was not impressed and would not go b...      0  ambiance
# 998  The whole experience was underwhelming, and I ...      0     value
# 999  Then, as if I hadn't wasted enough of my life ...      0      food
#
# [1000 rows x 3 columns]

# %%
print(data.head())
# Out:
#                                               Review  Liked Category
# 0                           Wow... Loved this place.      1  service
# 1                                 Crust is not good.      0     food
# 2          Not tasty and the texture was just nasty.      0    value
# 3  Stopped by during the late May bank holiday of...      1  service
# 4  The selection on the menu was great and so wer...      1  service

# %% [markdown]
# 2

# %%
import nltk
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
    t = re.sub(r'\W', ' ', text)
    t = re.sub(r'\s+', ' ', text)
    t = text.lower()
    words = t.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(words)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
data['Review'] = data['Review'].apply(preprocess_text)

# %%
vectorizer = TfidfVectorizer(max_features=500)
X = vectorizer.fit_transform(data['Review'])

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
labels = kmeans.labels_
cluster_names = {0: 'Food', 1: 'Service', 2: 'Ambiance'}

# %%
data['cluster'] = [cluster_names[label] for label in labels]
print(data[['Review', 'cluster']])
# Out:
#                                                 Review   cluster
# 0                                  wow... loved place.  Ambiance
# 1                                          crust good.  Ambiance
# 2                                 tasty texture nasty.   Service
# 3    stopped late may bank holiday rick steve recom...   Service
# 4                         selection menu great prices.   Service
# ..                                                 ...       ...
# 995                 think food flavor texture lacking.   Service
# 996                           appetite instantly gone.   Service
# 997                   overall impressed would go back.   Service
# 998  whole experience underwhelming, think we'll go...   Service
# 999  then, wasted enough life there, poured salt wo...   Service
#
# [1000 rows x 2 columns]

# %%
for cluster in data['cluster'].unique():
    print("Cluster:",cluster)
    print(data[data['cluster'] == cluster]['Review'].tolist())
    print("\n")
# Out:
# Cluster: Ambiance
# ['wow... loved place.', 'crust good.', 'place worth time, let alone vegas.', "that's right....the red velvet cake.....ohhh stuff good.", 'found place accident could happier.', 'seems like good quick place grab bite familiar pub food, favor look elsewhere.', 'overall, like place lot.', 'ample portion good prices.', 'deal good enough would drag establishment again.', 'hard judge whether side good grossed melted styrofoam want eat fear getting sick.', 'burger good beef, cooked right.', 'chow mein good!', 'place receives star appetizers!!!', 'glad found place.', '- really, really good rice, time.', 'guess known place would suck, inside excalibur, use common sense.', 'sweet potato fry good seasoned well.', "today second time i've lunch buffet pretty good.", 'much good food vega feel cheated wasting eating opportunity going rice company.', 'walked place smelled like old grease trap 2 others eating.', 'place it!', 'good.', 'side, cafe serf really good food.', "good thing waiter, helpful kept bloddy mary's coming.", 'sooooo good!!', "real sushi lovers, let's honest - yama good.", 'good prices.', 'know place managed served blandest food ever eaten preparing indian cuisine.', 'thought venture away get good sushi, place really hit spot night.', 'place way overpriced mediocre food.', 'good selection food including massive meatloaf sandwich, crispy chicken wrap, delish tuna melt tasty burgers.', 'delicious nyc bagels, good selection cream cheese, real lox caper even.', 'great subway, fact good come every subway meet expectations.', 'bathroom clean place well decorated.', 'place good.', 'place hands-down one best place eat phoenix metro area.', 'go looking good food...', 'weekly haunt, definitely place come back every while.', 'love place, hit spot want something healthy lacking quantity flavor.', 'heard good thing place, exceeding every hope could dreamed of.', 'good lunch spot.', 'must night place.', 'waitress good though!', 'soggy good.', 'place first pho amazing!!', 'wonderful experience made place must-stop whenever town again.', "great place couple drink watch sporting event wall covered tv's.", 'like reviewer said "you pay eat place again."', 'much better ayce sushi place went vegas.', 'overall, think would take parent place made similar complaint silently felt too.', 'pizza good peanut sauce tasty.', 'hope place stick around.', 'good service, clean, inexpensive, boot!', 'good year ago!', 'stopped place madison ironman, friendly, kind staff.', 'chef friendly good job.', 'place quality sushi, quality restaurant.', 'place amazing!', 'hate disagree fellow yelpers, husband disappointed place.', 'never dining place!', 'food excellent service good.', 'good beer & drink selection good food selection.', 'good service-check!', 'expect good!', 'food good.', 'point, friend basically figured place joke mind making publicly loudly known.', 'back good bbq, lighter fare, reasonable pricing tell public back old ways.', 'service exceptional food good reviews.', 'favorite place town shawarrrrrrma!!!!!!', 'could serve vinaigrette may make better overall dish, still good.', 'truly unbelievably good, glad went back.', 'love place.', 'nothing authentic place.', 'pretty good beer selection too.', 'place like chipotle, better.', 'good side, staff genuinely pleasant enthusiastic - real treat.', "sadly, gordon ramsey's steak place shall sharply avoid next trip vegas.", 'interesting part town, place amazing.', 'place deserves one star 90% food.', 'want healthy authentic ethic food, try place.', 'continue come lady night andddd date night ... highly recommend place anyone area.', 'great place eat, reminds little mom pop shop san francisco bay area.', 'food really good got full petty fast.', "seriously good pizza i'm expert/connisseur topic.", 'far sushi connoisseur definitely tell difference good food bad food certainly bad food.', 'food good enjoyed every mouthful, enjoyable relaxed venue couple small family group etc.', 'loved place.', 'good, though!', "place ...
#
#
# Cluster: Service
# ['tasty texture nasty.', 'stopped late may bank holiday rick steve recommendation loved it.', 'selection menu great prices.', 'getting angry want damn pho.', 'honeslty taste fresh.)', 'potato like rubber could tell made ahead time kept warmer.', 'fry great too.', 'great touch.', 'service prompt.', 'would go back.', 'cashier care ever say still ended wayyy overpriced.', 'tried cape cod ravoli, chicken, cranberry...mmmm!', 'disgusted pretty sure human hair.', 'shocked sign indicate cash only.', 'highly recommended.', 'waitress little slow service.', 'like all.', 'burrittos blah!', 'food, amazing.', 'service also cute.', 'could care less... interior beautiful.', 'performed.', '- never brought salad asked for.', 'hole wall great mexican street tacos, friendly staff.', 'took hour get food 4 table restaurant food luke warm, sever running around like totally overwhelmed.', 'worst salmon sashimi.', 'also combo like burger, fries, beer 23 decent deal.', 'like final blow!', 'redeeming quality restaurant inexpensive.', 'poor service, waiter made feel like stupid every time came table.', 'first visit hiro delight!', 'service sucks.', 'shrimp tender moist.', 'positive note, server attentive provided great service.', 'frozen puck disgust, worst people behind register.', 'thing like prime rib dessert section.', 'bad food damn generic.', 'want sandwich go firehouse!!!!!', 'side greek salad greek dressing tasty, pita hummus refreshing.', 'ordered duck rare pink tender inside nice char outside.', 'came running u realized husband left sunglass table.', 'horrible attitude towards customers, talk one customer enjoy food.', 'portion huge!', 'loved it...friendly servers, great food, wonderful imaginative menu.', 'heart attack grill downtown vega absolutely flat-lined excuse restaurant.', 'much seafood like 5 string pasta bottom.', 'salad right amount sauce power scallop, perfectly cooked.', 'ripped banana ripped, petrified tasteless.', 'least think refill water struggle wave 10 minutes.', 'cocktail handmade delicious.', "we'd definitely go back again.", 'great food service, huge portion give military discount.', 'always great time do gringos!', 'update.....went back second time still amazing', 'got food apparently never heard salt batter fish chewy.', 'great way finish great.', 'deal included 5 tasting 2 drinks, jeff went beyond expected.', 'service meh.', 'took 30 min get milkshake, nothing chocolate milk.', 'scallop dish quite appalling value well.', '2 time - bad customer service !', "coming like experiencing underwhelming relationship party can't wait person ask break up.", 'turkey roast beef bland.', 'pan cake everyone raving taste like sugary disaster tailored palate six year old.', 'love pho spring roll oh yummy try.', 'poor batter meat ratio made chicken tender unsatisfying.', 'say food amazing!!!', 'omelet die for!', 'everything fresh delicious!', 'summary, largely disappointing dining experience.', 'like really sexy party mouth, outrageously flirting hottest person party.', 'never hard rock casino before, never ever step forward again!', 'say bye bye tip lady!', "we'll never go again.", 'back again!', 'food arrived quickly!', 'server fantastic found wife love roasted garlic bone marrow, added extra meal another marrow go!', 'loved mussel cooked wine reduction, duck tender, potato dish delicious.', 'one better buffet to.', 'went tigerlilly fantastic afternoon!', 'food delicious, bartender attentive personable got great deal!', 'ambience wonderful music playing.', 'go back next trip out.', 'least 40min passed u ordering food arriving, busy.', 'really fantastic thai restaurant definitely worth visit.', 'nice, spicy tender.', 'check out.', 'pretty gross!', "i've better atmosphere.", 'kind hard mess steak did.', 'although much liked look sound place, actual experience bit disappointing.', 'worst service boot, least worries.', 'service fine waitress friendly.', 'host staff were, lack better word, bitches!', "bland... liking place number reason w ...
#
#
# Cluster: Food
# ['best breakfast buffet!!!', 'best buffet town, price cannot beat it.', "guy steaks, steak loving son steak best worst place said best steak he's ever eaten.", 'one best bar food vegas.', "i'm really sure joey's voted best hot dog valley reader phoenix magazine.", 'best place go tasty bowl pho!', 'dishes, salmon best, great.', "best fish i've ever life!", 'outstanding little restaurant best food ever tasted.', 'bean rice mediocre best.', 'best taco town far!!', 'know kind best iced tea.', 'best tater tot southwest.', 'selection food best.', 'far best cheesecurds ever had!', 'best place vega breakfast (just check sat, sun.', 'steak shrimp opinion best entree gc.', 'really enjoyed crema café expanded. even told friend best breakfast.', 'also best cheese crisp town.', 'best luck rude non-customer service focused new management.', 'food average best.', 'steak amazing...rge fillet relleno best seafood plate ever had!', 'pro : large seating area/ nice bar area/ great simple drink menu/ best brick oven pizza homemade dough!', 'lastly, mozzarella sticks, best thing ordered.', 'service fair best.', 'best service food ever, maria server good friendly made day.', 'feel dining room college cooking course high class dining service slow best.', "maybe vegetarian fare, i've twice thought average best."]
