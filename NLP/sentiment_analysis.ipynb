# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
a="/content/Restaurant_Reviews.tsv"
data=pd.read_csv(a,sep="\t")

# %%
data.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
data.dropna(inplace=True)

# %%
X=data['Review']
y=data['Liked']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=34)

# %% [markdown]
# preprocessing

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_rus is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker_tab is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger_tab to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger_tab is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]    |   Package punkt_tab is already up-to-date!
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package tagsets_json to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package tagsets_json is already up-to-date!
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
s = SentimentIntensityAnalyzer()

# %%
feedback = data['Review'].tolist()

# %%
for review in feedback:
    sentiment = s.polarity_scores(review)
    print("Feedback:" ,review)
    print("Scores:", sentiment)
    if sentiment['compound'] >= 0.05:
        print("ressult: Positive\n")
    elif sentiment['compound'] <= -0.05:
        print("result: Negative\n")
    else:
        print("result: Neutral\n")
# Out:
# Feedback: Wow... Loved this place.
# Scores: {'neg': 0.0, 'neu': 0.435, 'pos': 0.565, 'compound': 0.5994}
# ressult: Positive
#
# Feedback: Crust is not good.
# Scores: {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: Not tasty and the texture was just nasty.
# Scores: {'neg': 0.34, 'neu': 0.66, 'pos': 0.0, 'compound': -0.5574}
# result: Negative
#
# Feedback: Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# Scores: {'neg': 0.093, 'neu': 0.585, 'pos': 0.322, 'compound': 0.6908}
# ressult: Positive
#
# Feedback: The selection on the menu was great and so were the prices.
# Scores: {'neg': 0.0, 'neu': 0.728, 'pos': 0.272, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: Now I am getting angry and I want my damn pho.
# Scores: {'neg': 0.451, 'neu': 0.451, 'pos': 0.098, 'compound': -0.6908}
# result: Negative
#
# Feedback: Honeslty it didn't taste THAT fresh.)
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# Scores: {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'compound': 0.5719}
# ressult: Positive
#
# Feedback: The fries were great too.
# Scores: {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: A great touch.
# Scores: {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: Service was very prompt.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Would not go back.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.
# Scores: {'neg': 0.094, 'neu': 0.769, 'pos': 0.137, 'compound': 0.25}
# ressult: Positive
#
# Feedback: I tried the Cape Cod ravoli, chicken, with cranberry...mmmm!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I was disgusted because I was pretty sure that was human hair.
# Scores: {'neg': 0.214, 'neu': 0.44, 'pos': 0.346, 'compound': 0.2732}
# ressult: Positive
#
# Feedback: I was shocked because no signs indicate cash only.
# Scores: {'neg': 0.429, 'neu': 0.571, 'pos': 0.0, 'compound': -0.5423}
# result: Negative
#
# Feedback: Highly recommended.
# Scores: {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.2716}
# ressult: Positive
#
# Feedback: Waitress was a little slow in service.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This place is not worth your time, let alone Vegas.
# Scores: {'neg': 0.314, 'neu': 0.686, 'pos': 0.0, 'compound': -0.3952}
# result: Negative
#
# Feedback: did not like at all.
# Scores: {'neg': 0.345, 'neu': 0.655, 'pos': 0.0, 'compound': -0.2755}
# result: Negative
#
# Feedback: The Burrittos Blah!
# Scores: {'neg': 0.458, 'neu': 0.542, 'pos': 0.0, 'compound': -0.1759}
# result: Negative
#
# Feedback: The food, amazing.
# Scores: {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'compound': 0.5859}
# ressult: Positive
#
# Feedback: Service is also cute.
# Scores: {'neg': 0.0, 'neu': 0.5, 'pos': 0.5, 'compound': 0.4588}
# ressult: Positive
#
# Feedback: I could care less... The interior is just beautiful.
# Scores: {'neg': 0.0, 'neu': 0.458, 'pos': 0.542, 'compound': 0.7964}
# ressult: Positive
#
# Feedback: So they performed.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: That's right....the red velvet cake.....ohhh this stuff is so good.
# Scores: {'neg': 0.0, 'neu': 0.706, 'pos': 0.294, 'compound': 0.5777}
# ressult: Positive
#
# Feedback: - They never brought a salad we asked for.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This hole in the wall has great Mexican street tacos, and friendly staff.
# Scores: {'neg': 0.0, 'neu': 0.601, 'pos': 0.399, 'compound': 0.8074}
# ressult: Positive
#
# Feedback: Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.
# Scores: {'neg': 0.0, 'neu': 0.796, 'pos': 0.204, 'compound': 0.5984}
# ressult: Positive
#
# Feedback: The worst was the salmon sashimi.
# Scores: {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}
# result: Negative
#
# Feedback: Also there are combos like a burger, fries, and beer for 23 which is a decent deal.
# Scores: {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: This was like the final blow!
# Scores: {'neg': 0.0, 'neu': 0.642, 'pos': 0.358, 'compound': 0.4199}
# ressult: Positive
#
# Feedback: I found this place by accident and I could not be happier.
# Scores: {'neg': 0.423, 'neu': 0.577, 'pos': 0.0, 'compound': -0.7074}
# result: Negative
#
# Feedback: seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.
# Scores: {'neg': 0.0, 'neu': 0.701, 'pos': 0.299, 'compound': 0.7391}
# ressult: Positive
#
# Feedback: Overall, I like this place a lot.
# Scores: {'neg': 0.0, 'neu': 0.615, 'pos': 0.385, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: The only redeeming quality of the restaurant was that it was very inexpensive.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Ample portions and good prices.
# Scores: {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: Poor service, the waiter made me feel like I was stupid every time he came to the table.
# Scores: {'neg': 0.283, 'neu': 0.609, 'pos': 0.109, 'compound': -0.6124}
# result: Negative
#
# Feedback: My first visit to Hiro was a delight!
# Scores: {'neg': 0.0, 'neu': 0.589, 'pos': 0.411, 'compound': 0.636}
# ressult: Positive
#
# Feedback: Service sucks.
# Scores: {'neg': 0.714, 'neu': 0.286, 'pos': 0.0, 'compound': -0.3612}
# result: Negative
#
# Feedback: The shrimp tender and moist.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: There is not a deal good enough that would drag me into that establishment again.
# Scores: {'neg': 0.264, 'neu': 0.736, 'pos': 0.0, 'compound': -0.5116}
# result: Negative
#
# Feedback: Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.
# Scores: {'neg': 0.297, 'neu': 0.621, 'pos': 0.082, 'compound': -0.683}
# result: Negative
#
# Feedback: On a positive note, our server was very attentive and provided great service.
# Scores: {'neg': 0.0, 'neu': 0.565, 'pos': 0.435, 'compound': 0.8271}
# ressult: Positive
#
# Feedback: Frozen pucks of disgust, with some of the worst people behind the register.
# Scores: {'neg': 0.421, 'neu': 0.579, 'pos': 0.0, 'compound': -0.8402}
# result: Negative
#
# Feedback: The only thing I did like was the prime rib and dessert section.
# Scores: {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: It's too bad the food is so damn generic.
# Scores: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.79}
# result: Negative
#
# Feedback: The burger is good beef, cooked just right.
# Scores: {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: If you want a sandwich just go to any Firehouse!!!!!
# Scores: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.3544}
# ressult: Positive
#
# Feedback: My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.
# Scores: {'neg': 0.159, 'neu': 0.841, 'pos': 0.0, 'compound': -0.5267}
# result: Negative
#
# Feedback: We ordered the duck rare and it was pink and tender on the inside with a nice char on the outside.
# Scores: {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
# ressult: Positive
#
# Feedback: He came running after us when he realized my husband had left his sunglasses on the table.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Their chow mein is so good!
# Scores: {'neg': 0.0, 'neu': 0.554, 'pos': 0.446, 'compound': 0.6166}
# ressult: Positive
#
# Feedback: They have horrible attitudes towards customers, and talk down to each one when customers don't enjoy their food.
# Scores: {'neg': 0.277, 'neu': 0.723, 'pos': 0.0, 'compound': -0.7293}
# result: Negative
#
# Feedback: The portion was huge!
# Scores: {'neg': 0.0, 'neu': 0.536, 'pos': 0.464, 'compound': 0.3802}
# ressult: Positive
#
# Feedback: Loved it...friendly servers, great food, wonderful and imaginative menu.
# Scores: {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.9136}
# ressult: Positive
#
# Feedback: The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.
# Scores: {'neg': 0.186, 'neu': 0.719, 'pos': 0.095, 'compound': -0.3657}
# result: Negative
#
# Feedback: Not much seafood and like 5 strings of pasta at the bottom.
# Scores: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: The salad had just the right amount of sauce to not over power the scallop, which was perfectly cooked.
# Scores: {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: The ripped banana was not only ripped, but petrified and tasteless.
# Scores: {'neg': 0.322, 'neu': 0.678, 'pos': 0.0, 'compound': -0.6956}
# result: Negative
#
# Feedback: At least think to refill my water before I struggle to wave you over for 10 minutes.
# Scores: {'neg': 0.133, 'neu': 0.867, 'pos': 0.0, 'compound': -0.3182}
# result: Negative
#
# Feedback: This place receives stars for their APPETIZERS!!!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The cocktails are all handmade and delicious.
# Scores: {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.5719}
# ressult: Positive
#
# Feedback: We'd definitely go back here again.
# Scores: {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.4019}
# ressult: Positive
#
# Feedback: We are so glad we found this place.
# Scores: {'neg': 0.0, 'neu': 0.644, 'pos': 0.356, 'compound': 0.5949}
# ressult: Positive
#
# Feedback: Great food and service, huge portions and they give a military discount.
# Scores: {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.7506}
# ressult: Positive
#
# Feedback: Always a great time at Dos Gringos!
# Scores: {'neg': 0.0, 'neu': 0.532, 'pos': 0.468, 'compound': 0.6588}
# ressult: Positive
#
# Feedback: Update.....went back for a second time and it was still just as amazing
# Scores: {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.5859}
# ressult: Positive
#
# Feedback: We got the food and apparently they have never heard of salt and the batter on the fish was chewy.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: A great way to finish a great.
# Scores: {'neg': 0.0, 'neu': 0.268, 'pos': 0.732, 'compound': 0.8481}
# ressult: Positive
#
# Feedback: The deal included 5 tastings and 2 drinks, and Jeff went above and beyond what we expected.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: - Really, really good rice, all the time.
# Scores: {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'compound': 0.5379}
# ressult: Positive
#
# Feedback: The service was meh.
# Scores: {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'compound': -0.0772}
# result: Negative
#
# Feedback: It took over 30 min to get their milkshake, which was nothing more than chocolate milk.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I guess I should have known that this place would suck, because it is inside of the Excalibur, but I didn't use my common sense.
# Scores: {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'compound': -0.2382}
# result: Negative
#
# Feedback: The scallop dish is quite appalling for value as well.
# Scores: {'neg': 0.192, 'neu': 0.481, 'pos': 0.327, 'compound': 0.2431}
# ressult: Positive
#
# Feedback: 2 times - Very Bad Customer Service !
# Scores: {'neg': 0.505, 'neu': 0.495, 'pos': 0.0, 'compound': -0.623}
# result: Negative
#
# Feedback: The sweet potato fries were very good and seasoned well.
# Scores: {'neg': 0.0, 'neu': 0.458, 'pos': 0.542, 'compound': 0.807}
# ressult: Positive
#
# Feedback: Today is the second time I've been to their lunch buffet and it was pretty good.
# Scores: {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.7269}
# ressult: Positive
#
# Feedback: There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.
# Scores: {'neg': 0.2, 'neu': 0.6, 'pos': 0.199, 'compound': -0.0056}
# result: Neutral
#
# Feedback: Coming here is like experiencing an underwhelming relationship where both parties can't wait for the other person to ask to break up.
# Scores: {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: walked in and the place smelled like an old grease trap and only 2 others there eating.
# Scores: {'neg': 0.122, 'neu': 0.745, 'pos': 0.133, 'compound': 0.0516}
# ressult: Positive
#
# Feedback: The turkey and roast beef were bland.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This place has it!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The pan cakes everyone are raving about taste like a sugary disaster tailored to the palate of a six year old.
# Scores: {'neg': 0.174, 'neu': 0.72, 'pos': 0.106, 'compound': -0.3818}
# result: Negative
#
# Feedback: I love the Pho and the spring rolls oh so yummy you have to try.
# Scores: {'neg': 0.0, 'neu': 0.583, 'pos': 0.417, 'compound': 0.8613}
# ressult: Positive
#
# Feedback: The poor batter to meat ratio made the chicken tenders very unsatisfying.
# Scores: {'neg': 0.211, 'neu': 0.68, 'pos': 0.109, 'compound': -0.3612}
# result: Negative
#
# Feedback: All I have to say is the food was amazing!!!
# Scores: {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6884}
# ressult: Positive
#
# Feedback: Omelets are to die for!
# Scores: {'neg': 0.512, 'neu': 0.488, 'pos': 0.0, 'compound': -0.636}
# result: Negative
#
# Feedback: Everything was fresh and delicious!
# Scores: {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.7424}
# ressult: Positive
#
# Feedback: In summary, this was a largely disappointing dining experience.
# Scores: {'neg': 0.314, 'neu': 0.686, 'pos': 0.0, 'compound': -0.4939}
# result: Negative
#
# Feedback: It's like a really sexy party in your mouth, where you're outrageously flirting with the hottest person at the party.
# Scores: {'neg': 0.075, 'neu': 0.446, 'pos': 0.479, 'compound': 0.8945}
# ressult: Positive
#
# Feedback: Never been to Hard Rock Casino before, WILL NEVER EVER STEP FORWARD IN IT AGAIN!
# Scores: {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.1501}
# ressult: Positive
#
# Feedback: Best breakfast buffet!!!
# Scores: {'neg': 0.0, 'neu': 0.283, 'pos': 0.717, 'compound': 0.7249}
# ressult: Positive
#
# Feedback: say bye bye to your tip lady!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We'll never go again.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Will be back again!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Food arrived quickly!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: It was not good.
# Scores: {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: On the up side, their cafe serves really good food.
# Scores: {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4927}
# ressult: Positive
#
# Feedback: Our server was fantastic and when he found out the wife loves roasted garlic and bone marrow, he added extra to our meal and another marrow to go!
# Scores: {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.8221}
# ressult: Positive
#
# Feedback: The only good thing was our waiter, he was very helpful and kept the bloddy mary's coming.
# Scores: {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.7178}
# ressult: Positive
#
# Feedback: Best Buffet in town, for the price you cannot beat it.
# Scores: {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: I LOVED their mussels cooked in this wine reduction, the duck was tender, and their potato dishes were delicious.
# Scores: {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.8531}
# ressult: Positive
#
# Feedback: This is one of the better buffets that I have been to.
# Scores: {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: So we went to Tigerlilly and had a fantastic afternoon!
# Scores: {'neg': 0.0, 'neu': 0.673, 'pos': 0.327, 'compound': 0.5983}
# ressult: Positive
#
# Feedback: The food was delicious, our bartender was attentive and personable AND we got a great deal!
# Scores: {'neg': 0.0, 'neu': 0.616, 'pos': 0.384, 'compound': 0.8439}
# ressult: Positive
#
# Feedback: The ambience is wonderful and there is music playing.
# Scores: {'neg': 0.0, 'neu': 0.56, 'pos': 0.44, 'compound': 0.6705}
# ressult: Positive
#
# Feedback: Will go back next trip out.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Sooooo good!!
# Scores: {'neg': 0.0, 'neu': 0.223, 'pos': 0.777, 'compound': 0.5399}
# ressult: Positive
#
# Feedback: REAL sushi lovers, let's be honest - Yama is not that good.
# Scores: {'neg': 0.141, 'neu': 0.468, 'pos': 0.392, 'compound': 0.6479}
# ressult: Positive
#
# Feedback: At least 40min passed in between us ordering and the food arriving, and it wasn't that busy.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This is a really fantastic Thai restaurant which is definitely worth a visit.
# Scores: {'neg': 0.0, 'neu': 0.485, 'pos': 0.515, 'compound': 0.8173}
# ressult: Positive
#
# Feedback: Nice, spicy and tender.
# Scores: {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.4215}
# ressult: Positive
#
# Feedback: Good prices.
# Scores: {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: Check it out.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: It was pretty gross!
# Scores: {'neg': 0.361, 'neu': 0.233, 'pos': 0.406, 'compound': 0.1007}
# ressult: Positive
#
# Feedback: I've had better atmosphere.
# Scores: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: Kind of hard to mess up a steak but they did.
# Scores: {'neg': 0.269, 'neu': 0.731, 'pos': 0.0, 'compound': -0.2382}
# result: Negative
#
# Feedback: Although I very much liked the look and sound of this place, the actual experience was a bit disappointing.
# Scores: {'neg': 0.15, 'neu': 0.705, 'pos': 0.145, 'compound': -0.0314}
# result: Neutral
#
# Feedback: I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Worst service to boot, but that is the least of their worries.
# Scores: {'neg': 0.385, 'neu': 0.615, 'pos': 0.0, 'compound': -0.7391}
# result: Negative
#
# Feedback: Service was fine and the waitress was friendly.
# Scores: {'neg': 0.0, 'neu': 0.545, 'pos': 0.455, 'compound': 0.6124}
# ressult: Positive
#
# Feedback: The guys all had steaks, and our steak loving son who has had steak at the best and worst places said it was the best steak he's ever eaten.
# Scores: {'neg': 0.099, 'neu': 0.604, 'pos': 0.297, 'compound': 0.8481}
# ressult: Positive
#
# Feedback: We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.
# Scores: {'neg': 0.0, 'neu': 0.911, 'pos': 0.089, 'compound': 0.2382}
# ressult: Positive
#
# Feedback: Host staff were, for lack of a better word, BITCHES!
# Scores: {'neg': 0.448, 'neu': 0.372, 'pos': 0.18, 'compound': -0.6514}
# result: Negative
#
# Feedback: Bland... Not a liking this place for a number of reasons and I don't want to waste time on bad reviewing.. I'll leave it at that...
# Scores: {'neg': 0.284, 'neu': 0.59, 'pos': 0.126, 'compound': -0.5496}
# result: Negative
#
# Feedback: Phenomenal food, service and ambiance.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I wouldn't return.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Definitely worth venturing off the strip for the pork belly, will return next time I'm in Vegas.
# Scores: {'neg': 0.0, 'neu': 0.765, 'pos': 0.235, 'compound': 0.5574}
# ressult: Positive
#
# Feedback: This place is way too overpriced for mediocre food.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Penne vodka excellent!
# Scores: {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6114}
# ressult: Positive
#
# Feedback: They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.
# Scores: {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: The management is rude.
# Scores: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.4588}
# result: Negative
#
# Feedback: Delicious NYC bagels, good selections of cream cheese, real Lox with capers even.
# Scores: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.765}
# ressult: Positive
#
# Feedback: Great Subway, in fact it's so good when you come here every other Subway will not meet your expectations.
# Scores: {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.8334}
# ressult: Positive
#
# Feedback: I had a seriously solid breakfast here.
# Scores: {'neg': 0.27, 'neu': 0.476, 'pos': 0.254, 'compound': -0.0258}
# result: Neutral
#
# Feedback: This is one of the best bars with food in Vegas.
# Scores: {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: He was extremely rude and really, there are so many other restaurants I would love to dine at during a weekend in Vegas.
# Scores: {'neg': 0.124, 'neu': 0.717, 'pos': 0.159, 'compound': 0.228}
# ressult: Positive
#
# Feedback: My drink was never empty and he made some really great menu suggestions.
# Scores: {'neg': 0.0, 'neu': 0.648, 'pos': 0.352, 'compound': 0.7171}
# ressult: Positive
#
# Feedback: Don't do it!!!!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The waiter wasn't helpful or friendly and rarely checked on us.
# Scores: {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.6072}
# result: Negative
#
# Feedback: My husband and I ate lunch here and were very disappointed with the food and service.
# Scores: {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.5256}
# result: Negative
#
# Feedback: And the red curry had so much bamboo shoots and wasn't very tasty to me.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Nice blanket of moz over top but i feel like this was done to cover up the subpar food.
# Scores: {'neg': 0.0, 'neu': 0.696, 'pos': 0.304, 'compound': 0.6757}
# ressult: Positive
#
# Feedback: The bathrooms are clean and the place itself is well decorated.
# Scores: {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.5859}
# ressult: Positive
#
# Feedback: The menu is always changing, food quality is going down & service is extremely slow.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I give it 2 thumbs down
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We watched our waiter pay a lot more attention to other tables and ignore us.
# Scores: {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'compound': -0.4404}
# result: Negative
#
# Feedback: My fiancé and I came in the middle of the day and we were greeted and seated right away.
# Scores: {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compound': 0.2732}
# ressult: Positive
#
# Feedback: This is a great restaurant at the Mandalay Bay.
# Scores: {'neg': 0.0, 'neu': 0.631, 'pos': 0.369, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: We waited for forty five minutes in vain.
# Scores: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.4215}
# result: Negative
#
# Feedback: Crostini that came with the salad was stale.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Some highlights : Great quality nigiri here!
# Scores: {'neg': 0.0, 'neu': 0.532, 'pos': 0.468, 'compound': 0.6588}
# ressult: Positive
#
# Feedback: the staff is friendly and the joint is always clean.
# Scores: {'neg': 0.0, 'neu': 0.576, 'pos': 0.424, 'compound': 0.7096}
# ressult: Positive
#
# Feedback: this was a different cut than the piece the other day but still wonderful and tender s well as well flavored.
# Scores: {'neg': 0.058, 'neu': 0.558, 'pos': 0.385, 'compound': 0.8689}
# ressult: Positive
#
# Feedback: I ordered the Voodoo pasta and it was the first time I'd had really excellent pasta since going gluten free several years ago.
# Scores: {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.807}
# ressult: Positive
#
# Feedback: this place is good.
# Scores: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: Unfortunately, we must have hit the bakery on leftover day because everything we ordered was STALE.
# Scores: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.34}
# result: Negative
#
# Feedback: I came back today since they relocated and still not impressed.
# Scores: {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'compound': -0.3724}
# result: Negative
#
# Feedback: I was seated immediately.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Their menu is diverse, and reasonably priced.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Avoid at all cost!
# Scores: {'neg': 0.454, 'neu': 0.546, 'pos': 0.0, 'compound': -0.3595}
# result: Negative
#
# Feedback: Restaurant is always full but never a wait.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: DELICIOUS!!
# Scores: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6467}
# ressult: Positive
#
# Feedback: This place is hands-down one of the best places to eat in the Phoenix metro area.
# Scores: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: So don't go there if you are looking for good food...
# Scores: {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: I've never been treated so bad.
# Scores: {'neg': 0.473, 'neu': 0.527, 'pos': 0.0, 'compound': -0.6696}
# result: Negative
#
# Feedback: Bacon is hella salty.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We also ordered the spinach and avocado salad, the ingredients were sad and the dressing literally had zero taste.
# Scores: {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.4767}
# result: Negative
#
# Feedback: This really is how Vegas fine dining used to be, right down to the menus handed to the ladies that have no prices listed.
# Scores: {'neg': 0.085, 'neu': 0.846, 'pos': 0.069, 'compound': -0.1027}
# result: Negative
#
# Feedback: The waitresses are very friendly.
# Scores: {'neg': 0.0, 'neu': 0.534, 'pos': 0.466, 'compound': 0.5413}
# ressult: Positive
#
# Feedback: Lordy, the Khao Soi is a dish that is not to be missed for curry lovers!
# Scores: {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.6788}
# ressult: Positive
#
# Feedback: Everything on the menu is terrific and we were also thrilled that they made amazing accommodations for our vegetarian daughter.
# Scores: {'neg': 0.0, 'neu': 0.634, 'pos': 0.366, 'compound': 0.8689}
# ressult: Positive
#
# Feedback: Perhaps I caught them on an off night judging by the other reviews, but I'm not inspired to go back.
# Scores: {'neg': 0.161, 'neu': 0.839, 'pos': 0.0, 'compound': -0.5334}
# result: Negative
#
# Feedback: The service here leaves a lot to be desired.
# Scores: {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.2732}
# ressult: Positive
#
# Feedback: The atmosphere is modern and hip, while maintaining a touch of coziness.
# Scores: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: Not a weekly haunt, but definitely a place to come back to every once in a while.
# Scores: {'neg': 0.0, 'neu': 0.699, 'pos': 0.301, 'compound': 0.6345}
# ressult: Positive
#
# Feedback: We literally sat there for 20 minutes with no one asking to take our order.
# Scores: {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.296}
# result: Negative
#
# Feedback: The burger had absolutely no flavor - the meat itself was totally bland, the burger was overcooked and there was no charcoal flavor.
# Scores: {'neg': 0.2, 'neu': 0.8, 'pos': 0.0, 'compound': -0.6106}
# result: Negative
#
# Feedback: I also decided not to send it back because our waitress looked like she was on the verge of having a heart attack.
# Scores: {'neg': 0.126, 'neu': 0.772, 'pos': 0.102, 'compound': -0.1531}
# result: Negative
#
# Feedback: I dressed up to be treated so rudely!
# Scores: {'neg': 0.424, 'neu': 0.576, 'pos': 0.0, 'compound': -0.6606}
# result: Negative
#
# Feedback: It was probably dirt.
# Scores: {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.34}
# result: Negative
#
# Feedback: Love this place, hits the spot when I want something healthy but not lacking in quantity or flavor.
# Scores: {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'compound': 0.5574}
# ressult: Positive
#
# Feedback: I ordered the Lemon raspberry ice cocktail which was also incredible.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The food sucked, which we expected but it sucked more than we could have imagined.
# Scores: {'neg': 0.316, 'neu': 0.684, 'pos': 0.0, 'compound': -0.7184}
# result: Negative
#
# Feedback: Interesting decor.
# Scores: {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compound': 0.4019}
# ressult: Positive
#
# Feedback: What I really like there is the crepe station.
# Scores: {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.4201}
# ressult: Positive
#
# Feedback: Also were served hot bread and butter, and home made potato chips with bacon bits on top....very original and very good.
# Scores: {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.6697}
# ressult: Positive
#
# Feedback: you can watch them preparing the delicious food!)
# Scores: {'neg': 0.0, 'neu': 0.637, 'pos': 0.363, 'compound': 0.6114}
# ressult: Positive
#
# Feedback: Both of the egg rolls were fantastic.
# Scores: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.5574}
# ressult: Positive
#
# Feedback: When my order arrived, one of the gyros was missing.
# Scores: {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}
# result: Negative
#
# Feedback: I had a salad with the wings, and some ice cream for dessert and left feeling quite satisfied.
# Scores: {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.5563}
# ressult: Positive
#
# Feedback: I'm not really sure how Joey's was voted best hot dog in the Valley by readers of Phoenix Magazine.
# Scores: {'neg': 0.093, 'neu': 0.727, 'pos': 0.18, 'compound': 0.4627}
# ressult: Positive
#
# Feedback: The best place to go for a tasty bowl of Pho!
# Scores: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6696}
# ressult: Positive
#
# Feedback: The live music on Fridays totally blows.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I've never been more insulted or felt disrespected.
# Scores: {'neg': 0.252, 'neu': 0.503, 'pos': 0.245, 'compound': -0.021}
# result: Neutral
#
# Feedback: Very friendly staff.
# Scores: {'neg': 0.0, 'neu': 0.364, 'pos': 0.636, 'compound': 0.5413}
# ressult: Positive
#
# Feedback: It is worth the drive.
# Scores: {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'compound': 0.2263}
# ressult: Positive
#
# Feedback: I had heard good things about this place, but it exceeding every hope I could have dreamed of.
# Scores: {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.7003}
# ressult: Positive
#
# Feedback: Food was great and so was the serivce!
# Scores: {'neg': 0.0, 'neu': 0.614, 'pos': 0.386, 'compound': 0.6588}
# ressult: Positive
#
# Feedback: The warm beer didn't help.
# Scores: {'neg': 0.315, 'neu': 0.419, 'pos': 0.265, 'compound': -0.092}
# result: Negative
#
# Feedback: Great brunch spot.
# Scores: {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: Service is friendly and inviting.
# Scores: {'neg': 0.0, 'neu': 0.353, 'pos': 0.647, 'compound': 0.6705}
# ressult: Positive
#
# Feedback: Very good lunch spot.
# Scores: {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4927}
# ressult: Positive
#
# Feedback: I've lived here since 1979 and this was the first (and last) time I've stepped foot into this place.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The WORST EXPERIENCE EVER.
# Scores: {'neg': 0.617, 'neu': 0.383, 'pos': 0.0, 'compound': -0.7034}
# result: Negative
#
# Feedback: Must have been an off night at this place.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The sides are delish - mixed mushrooms, yukon gold puree, white corn - beateous.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: If that bug never showed up I would have given a 4 for sure, but on the other side of the wall where this bug was climbing was the kitchen.
# Scores: {'neg': 0.0, 'neu': 0.94, 'pos': 0.06, 'compound': 0.1655}
# ressult: Positive
#
# Feedback: For about 10 minutes, we we're waiting for her salad when we realized that it wasn't coming any time soon.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: My friend loved the salmon tartar.
# Scores: {'neg': 0.0, 'neu': 0.36, 'pos': 0.64, 'compound': 0.7964}
# ressult: Positive
#
# Feedback: Won't go back.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Extremely Tasty!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Waitress was good though!
# Scores: {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4926}
# ressult: Positive
#
# Feedback: Soggy and not good.
# Scores: {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: The Jamaican mojitos are delicious.
# Scores: {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'compound': 0.5719}
# ressult: Positive
#
# Feedback: Which are small and not worth the price.
# Scores: {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.1695}
# result: Negative
#
# Feedback: - the food is rich so order accordingly.
# Scores: {'neg': 0.0, 'neu': 0.625, 'pos': 0.375, 'compound': 0.5574}
# ressult: Positive
#
# Feedback: The shower area is outside so you can only rinse, not take a full shower, unless you don't mind being nude for everyone to see!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The service was a bit lacking.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Lobster Bisque, Bussell Sprouts, Risotto, Filet ALL needed salt and pepper..and of course there is none at the tables.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Hopefully this bodes for them going out of business and someone who can cook can come in.
# Scores: {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.4019}
# ressult: Positive
#
# Feedback: It was either too cold, not enough flavor or just bad.
# Scores: {'neg': 0.259, 'neu': 0.741, 'pos': 0.0, 'compound': -0.5423}
# result: Negative
#
# Feedback: I loved the bacon wrapped dates.
# Scores: {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.5994}
# ressult: Positive
#
# Feedback: This is an unbelievable BARGAIN!
# Scores: {'neg': 0.0, 'neu': 0.393, 'pos': 0.607, 'compound': 0.561}
# ressult: Positive
#
# Feedback: The folks at Otto always make us feel so welcome and special.
# Scores: {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'compound': 0.7802}
# ressult: Positive
#
# Feedback: As for the "mains," also uninspired.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This is the place where I first had pho and it was amazing!!
# Scores: {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.658}
# ressult: Positive
#
# Feedback: This wonderful experience made this place a must-stop whenever we are in town again.
# Scores: {'neg': 0.0, 'neu': 0.764, 'pos': 0.236, 'compound': 0.5719}
# ressult: Positive
#
# Feedback: If the food isn't bad enough for you, then enjoy dealing with the world's worst/annoying drunk people.
# Scores: {'neg': 0.107, 'neu': 0.624, 'pos': 0.269, 'compound': 0.5647}
# ressult: Positive
#
# Feedback: Very very fun chef.
# Scores: {'neg': 0.0, 'neu': 0.437, 'pos': 0.563, 'compound': 0.5956}
# ressult: Positive
#
# Feedback: Ordered a double cheeseburger & got a single patty that was falling apart (picture uploaded) Yeah, still sucks.
# Scores: {'neg': 0.224, 'neu': 0.656, 'pos': 0.12, 'compound': -0.2263}
# result: Negative
#
# Feedback: Great place to have a couple drinks and watch any and all sporting events as the walls are covered with TV's.
# Scores: {'neg': 0.0, 'neu': 0.823, 'pos': 0.177, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: If it were possible to give them zero stars, they'd have it.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The descriptions said "yum yum sauce" and another said "eel sauce", yet another said "spicy mayo"...well NONE of the rolls had sauces on them.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I'd say that would be the hardest decision... Honestly, all of M's dishes taste how they are supposed to taste (amazing).
# Scores: {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
# ressult: Positive
#
# Feedback: If she had not rolled the eyes we may have stayed... Not sure if we will go back and try it again.
# Scores: {'neg': 0.085, 'neu': 0.915, 'pos': 0.0, 'compound': -0.2411}
# result: Negative
#
# Feedback: Everyone is very attentive, providing excellent customer service.
# Scores: {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.6077}
# ressult: Positive
#
# Feedback: Horrible - don't waste your time and money.
# Scores: {'neg': 0.323, 'neu': 0.462, 'pos': 0.215, 'compound': -0.2887}
# result: Negative
#
# Feedback: Now this dish was quite flavourful.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: By this time our side of the restaurant was almost empty so there was no excuse.
# Scores: {'neg': 0.217, 'neu': 0.712, 'pos': 0.071, 'compound': -0.3961}
# result: Negative
#
# Feedback: (It wasn't busy either) Also, the building was FREEZING cold.
# Scores: {'neg': 0.192, 'neu': 0.808, 'pos': 0.0, 'compound': -0.2808}
# result: Negative
#
# Feedback: like the other reviewer said "you couldn't pay me to eat at this place again."
# Scores: {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.4207}
# ressult: Positive
#
# Feedback: -Drinks took close to 30 minutes to come out at one point.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Seriously flavorful delights, folks.
# Scores: {'neg': 0.254, 'neu': 0.299, 'pos': 0.448, 'compound': 0.3182}
# ressult: Positive
#
# Feedback: Much better than the other AYCE sushi place I went to in Vegas.
# Scores: {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: The lighting is just dark enough to set the mood.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Based on the sub-par service I received and no effort to show their gratitude for my business I won't be going back.
# Scores: {'neg': 0.094, 'neu': 0.766, 'pos': 0.14, 'compound': 0.2732}
# ressult: Positive
#
# Feedback: Owner's are really great people.!
# Scores: {'neg': 0.0, 'neu': 0.461, 'pos': 0.539, 'compound': 0.6893}
# ressult: Positive
#
# Feedback: There is nothing privileged about working/eating there.
# Scores: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: The Greek dressing was very creamy and flavorful.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Overall, I don't think that I would take my parents to this place again because they made most of the similar complaints that I silently felt too.
# Scores: {'neg': 0.105, 'neu': 0.895, 'pos': 0.0, 'compound': -0.4019}
# result: Negative
#
# Feedback: Now the pizza itself was good the peanut sauce was very tasty.
# Scores: {'neg': 0.0, 'neu': 0.791, 'pos': 0.209, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: We had 7 at our table and the service was pretty fast.
# Scores: {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4939}
# ressult: Positive
#
# Feedback: Fantastic service here.
# Scores: {'neg': 0.0, 'neu': 0.357, 'pos': 0.643, 'compound': 0.5574}
# ressult: Positive
#
# Feedback: I as well would've given godfathers zero stars if possible.
# Scores: {'neg': 0.0, 'neu': 0.792, 'pos': 0.208, 'compound': 0.2732}
# ressult: Positive
#
# Feedback: They know how to make them here.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: very tough and very short on flavor!
# Scores: {'neg': 0.258, 'neu': 0.742, 'pos': 0.0, 'compound': -0.2698}
# result: Negative
#
# Feedback: I hope this place sticks around.
# Scores: {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: I have been in more than a few bars in Vegas, and do not ever recall being charged for tap water.
# Scores: {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.2023}
# result: Negative
#
# Feedback: The restaurant atmosphere was exquisite.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Good service, very clean, and inexpensive, to boot!
# Scores: {'neg': 0.0, 'neu': 0.492, 'pos': 0.508, 'compound': 0.7339}
# ressult: Positive
#
# Feedback: The seafood was fresh and generous in portion.
# Scores: {'neg': 0.0, 'neu': 0.517, 'pos': 0.483, 'compound': 0.6808}
# ressult: Positive
#
# Feedback: Plus, it's only 8 bucks.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The service was not up to par, either.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Thus far, have only visited twice and the food was absolutely delicious each time.
# Scores: {'neg': 0.0, 'neu': 0.765, 'pos': 0.235, 'compound': 0.6115}
# ressult: Positive
#
# Feedback: Just as good as when I had it more than a year ago!
# Scores: {'neg': 0.0, 'neu': 0.758, 'pos': 0.242, 'compound': 0.4926}
# ressult: Positive
#
# Feedback: For a self proclaimed coffee cafe, I was wildly disappointed.
# Scores: {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.4767}
# result: Negative
#
# Feedback: The Veggitarian platter is out of this world!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: You cant go wrong with any of the food here.
# Scores: {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.3724}
# ressult: Positive
#
# Feedback: You can't beat that.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Stopped by this place while in Madison for the Ironman, very friendly, kind staff.
# Scores: {'neg': 0.095, 'neu': 0.548, 'pos': 0.357, 'compound': 0.7408}
# ressult: Positive
#
# Feedback: The chefs were friendly and did a good job.
# Scores: {'neg': 0.0, 'neu': 0.496, 'pos': 0.504, 'compound': 0.7269}
# ressult: Positive
#
# Feedback: I've had better, not only from dedicated boba tea spots, but even from Jenni Pho.
# Scores: {'neg': 0.104, 'neu': 0.779, 'pos': 0.117, 'compound': 0.0541}
# ressult: Positive
#
# Feedback: I liked the patio and the service was outstanding.
# Scores: {'neg': 0.0, 'neu': 0.469, 'pos': 0.531, 'compound': 0.7783}
# ressult: Positive
#
# Feedback: The goat taco didn't skimp on the meat and wow what FLAVOR!
# Scores: {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.6239}
# ressult: Positive
#
# Feedback: I think not again
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I had the mac salad and it was pretty bland so I will not be getting that again.
# Scores: {'neg': 0.0, 'neu': 0.824, 'pos': 0.176, 'compound': 0.4939}
# ressult: Positive
#
# Feedback: I went to Bachi Burger on a friend's recommendation and was not disappointed.
# Scores: {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.3724}
# ressult: Positive
#
# Feedback: Service stinks here!
# Scores: {'neg': 0.534, 'neu': 0.466, 'pos': 0.0, 'compound': -0.3164}
# result: Negative
#
# Feedback: I waited and waited.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This place is not quality sushi, it is not a quality restaurant.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I would definitely recommend the wings as well as the pizza.
# Scores: {'neg': 0.0, 'neu': 0.49, 'pos': 0.51, 'compound': 0.743}
# ressult: Positive
#
# Feedback: Great Pizza and Salads!
# Scores: {'neg': 0.0, 'neu': 0.406, 'pos': 0.594, 'compound': 0.6588}
# ressult: Positive
#
# Feedback: Things that went wrong: - They burned the saganaki.
# Scores: {'neg': 0.307, 'neu': 0.693, 'pos': 0.0, 'compound': -0.4767}
# result: Negative
#
# Feedback: We waited an hour for what was a breakfast I could have done 100 times better at home.
# Scores: {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: This place is amazing!
# Scores: {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'compound': 0.6239}
# ressult: Positive
#
# Feedback: I hate to disagree with my fellow Yelpers, but my husband and I were so disappointed with this place.
# Scores: {'neg': 0.408, 'neu': 0.592, 'pos': 0.0, 'compound': -0.8637}
# result: Negative
#
# Feedback: Waited 2 hours & never got either of our pizzas as many other around us who came in later did!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Just don't know why they were so slow.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The staff is great, the food is delish, and they have an incredible beer selection.
# Scores: {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.6249}
# ressult: Positive
#
# Feedback: I live in the neighborhood so I am disappointed I won't be back here, because it is a convenient location.
# Scores: {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.5233}
# result: Negative
#
# Feedback: I didn't know pulled pork could be soooo delicious.
# Scores: {'neg': 0.0, 'neu': 0.654, 'pos': 0.346, 'compound': 0.5719}
# ressult: Positive
#
# Feedback: You get incredibly fresh fish, prepared with care.
# Scores: {'neg': 0.0, 'neu': 0.386, 'pos': 0.614, 'compound': 0.788}
# ressult: Positive
#
# Feedback: Before I go in to why I gave a 1 star rating please know that this was my third time eating at Bachi burger before writing a review.
# Scores: {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.3182}
# ressult: Positive
#
# Feedback: I love the fact that everything on their menu is worth it.
# Scores: {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.7269}
# ressult: Positive
#
# Feedback: Never again will I be dining at this place!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The food was excellent and service was very good.
# Scores: {'neg': 0.0, 'neu': 0.504, 'pos': 0.496, 'compound': 0.7841}
# ressult: Positive
#
# Feedback: Good beer & drink selection and good food selection.
# Scores: {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.7003}
# ressult: Positive
#
# Feedback: Please stay away from the shrimp stir fried noodles.
# Scores: {'neg': 0.0, 'neu': 0.777, 'pos': 0.223, 'compound': 0.3182}
# ressult: Positive
#
# Feedback: The potato chip order was sad... I could probably count how many chips were in that box and it was probably around 12.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Food was really boring.
# Scores: {'neg': 0.464, 'neu': 0.536, 'pos': 0.0, 'compound': -0.3804}
# result: Negative
#
# Feedback: Good Service-check!
# ...
# ressult: Positive
#
# Feedback: Spend your money elsewhere.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Their regular toasted bread was equally satisfying with the occasional pats of butter... Mmmm...!
# Scores: {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.5093}
# ressult: Positive
#
# Feedback: The Buffet at Bellagio was far from what I anticipated.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: And the drinks are WEAK, people!
# Scores: {'neg': 0.44, 'neu': 0.56, 'pos': 0.0, 'compound': -0.6027}
# result: Negative
#
# Feedback: -My order was not correct.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Also, I feel like the chips are bought, not made in house.
# Scores: {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.3612}
# ressult: Positive
#
# Feedback: After the disappointing dinner we went elsewhere for dessert.
# Scores: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.4939}
# result: Negative
#
# Feedback: The chips and sals a here is amazing!!!!!!!!!!!!!!!!!!!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We won't be returning.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This is my new fav Vegas buffet spot.
# Scores: {'neg': 0.0, 'neu': 0.7, 'pos': 0.3, 'compound': 0.4588}
# ressult: Positive
#
# Feedback: I seriously cannot believe that the owner has so many unexperienced employees that all are running around like chickens with their heads cut off.
# Scores: {'neg': 0.144, 'neu': 0.76, 'pos': 0.095, 'compound': -0.0772}
# result: Negative
#
# Feedback: Very, very sad.
# Scores: {'neg': 0.647, 'neu': 0.353, 'pos': 0.0, 'compound': -0.5678}
# result: Negative
#
# Feedback: i felt insulted and disrespected, how could you talk and judge another human being like that?
# Scores: {'neg': 0.303, 'neu': 0.577, 'pos': 0.12, 'compound': -0.5859}
# result: Negative
#
# Feedback: How can you call yourself a steakhouse if you can't properly cook a steak, I don't understand!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I'm not impressed with the concept or the food.
# Scores: {'neg': 0.242, 'neu': 0.758, 'pos': 0.0, 'compound': -0.3724}
# result: Negative
#
# Feedback: The only thing I wasn't too crazy about was their guacamole as I don't like it puréed.
# Scores: {'neg': 0.123, 'neu': 0.758, 'pos': 0.119, 'compound': -0.0191}
# result: Neutral
#
# Feedback: There is really nothing for me at postinos, hope your experience is better
# Scores: {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'compound': 0.7003}
# ressult: Positive
#
# Feedback: I got food poisoning here at the buffet.
# Scores: {'neg': 0.388, 'neu': 0.612, 'pos': 0.0, 'compound': -0.5859}
# result: Negative
#
# Feedback: They brought a fresh batch of fries and I was thinking yay something warm but no!
# Scores: {'neg': 0.152, 'neu': 0.544, 'pos': 0.304, 'compound': 0.2003}
# ressult: Positive
#
# Feedback: What SHOULD have been a hilarious, yummy Christmas Eve dinner to remember was the biggest fail of the entire trip for us.
# Scores: {'neg': 0.127, 'neu': 0.652, 'pos': 0.221, 'compound': 0.3818}
# ressult: Positive
#
# Feedback: Needless to say, I won't be going back anytime soon.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: This place is disgusting!
# Scores: {'neg': 0.552, 'neu': 0.448, 'pos': 0.0, 'compound': -0.5707}
# result: Negative
#
# Feedback: Every time I eat here, I see caring teamwork to a professional degree.
# Scores: {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4939}
# ressult: Positive
#
# Feedback: The RI style calamari was a joke.
# Scores: {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'compound': 0.296}
# ressult: Positive
#
# Feedback: However, there was so much garlic in the fondue, it was barely edible.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I could barely stomach the meal, but didn't complain because it was a business lunch.
# Scores: {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.395}
# ressult: Positive
#
# Feedback: It was so bad, I had lost the heart to finish it.
# Scores: {'neg': 0.439, 'neu': 0.561, 'pos': 0.0, 'compound': -0.7938}
# result: Negative
#
# Feedback: It also took her forever to bring us the check when we asked for it.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We aren't ones to make a scene at restaurants but I just don't get it...definitely lost the love after this one!
# Scores: {'neg': 0.0, 'neu': 0.666, 'pos': 0.334, 'compound': 0.8603}
# ressult: Positive
#
# Feedback: Disappointing experience.
# Scores: {'neg': 0.762, 'neu': 0.238, 'pos': 0.0, 'compound': -0.4939}
# result: Negative
#
# Feedback: The food is about on par with Denny's, which is to say, not good at all.
# Scores: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: If you want to wait for mediocre food and downright terrible service, then this is the place for you.
# Scores: {'neg': 0.145, 'neu': 0.794, 'pos': 0.061, 'compound': -0.4215}
# result: Negative
#
# Feedback: WAAAAAAyyyyyyyyyy over rated is all I am saying.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: We won't be going back.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The place was fairly clean but the food simply wasn't worth it.
# Scores: {'neg': 0.144, 'neu': 0.722, 'pos': 0.134, 'compound': -0.0384}
# result: Neutral
#
# Feedback: This place lacked style!!
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The sangria was about half of a glass wine full and was $12, ridiculous.
# Scores: {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.3612}
# result: Negative
#
# Feedback: Don't bother coming here.
# Scores: {'neg': 0.0, 'neu': 0.596, 'pos': 0.404, 'compound': 0.2584}
# ressult: Positive
#
# Feedback: The meat was pretty dry, I had the sliced brisket and pulled pork.
# Scores: {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.4939}
# ressult: Positive
#
# Feedback: The building itself seems pretty neat, the bathroom is pretty trippy, but I wouldn't eat here again.
# Scores: {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.6369}
# ressult: Positive
#
# Feedback: It was equally awful.
# Scores: {'neg': 0.5, 'neu': 0.5, 'pos': 0.0, 'compound': -0.4588}
# result: Negative
#
# Feedback: Probably not in a hurry to go back.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: very slow at seating even with reservation.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Not good by any stretch of the imagination.
# Scores: {'neg': 0.256, 'neu': 0.744, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: The cashew cream sauce was bland and the vegetables were undercooked.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The chipolte ranch dipping sause was tasteless, seemed thin and watered down with no heat.
# Scores: {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.296}
# result: Negative
#
# Feedback: It was a bit too sweet, not really spicy enough, and lacked flavor.
# Scores: {'neg': 0.0, 'neu': 0.786, 'pos': 0.214, 'compound': 0.4588}
# ressult: Positive
#
# Feedback: I was VERY disappointed!!
# Scores: {'neg': 0.702, 'neu': 0.298, 'pos': 0.0, 'compound': -0.6917}
# result: Negative
#
# Feedback: This place is horrible and way overpriced.
# Scores: {'neg': 0.368, 'neu': 0.632, 'pos': 0.0, 'compound': -0.5423}
# result: Negative
#
# Feedback: Maybe it's just their Vegetarian fare, but I've been twice and I thought it was average at best.
# Scores: {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.7783}
# ressult: Positive
#
# Feedback: It wasn't busy at all and now we know why.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The tables outside are also dirty a lot of the time and the workers are not always friendly and helpful with the menu.
# Scores: {'neg': 0.202, 'neu': 0.695, 'pos': 0.102, 'compound': -0.4075}
# result: Negative
#
# Feedback: The ambiance here did not feel like a buffet setting, but more of a douchey indoor garden for tea and biscuits.
# Scores: {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.1419}
# result: Negative
#
# Feedback: Con: spotty service.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: The fries were not hot, and neither was my burger.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: But then they came back cold.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Then our food came out, disappointment ensued.
# Scores: {'neg': 0.355, 'neu': 0.645, 'pos': 0.0, 'compound': -0.5106}
# result: Negative
#
# Feedback: The real disappointment was our waiter.
# Scores: {'neg': 0.398, 'neu': 0.602, 'pos': 0.0, 'compound': -0.5106}
# result: Negative
#
# Feedback: My husband said she was very rude... did not even apologize for the bad food or anything.
# Scores: {'neg': 0.242, 'neu': 0.758, 'pos': 0.0, 'compound': -0.5853}
# result: Negative
#
# Feedback: The only reason to eat here would be to fill up before a night of binge drinking just to get some carbs in your stomach.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Insults, profound deuchebaggery, and had to go outside for a smoke break while serving just to solidify it.
# Scores: {'neg': 0.149, 'neu': 0.851, 'pos': 0.0, 'compound': -0.4215}
# result: Negative
#
# Feedback: If someone orders two tacos don't' you think it may be part of customer service to ask if it is combo or ala cart?
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: She was quite disappointed although some blame needs to be placed at her door.
# Scores: {'neg': 0.326, 'neu': 0.674, 'pos': 0.0, 'compound': -0.6997}
# result: Negative
#
# Feedback: After all the rave reviews I couldn't wait to eat here......what a disappointment!
# Scores: {'neg': 0.264, 'neu': 0.736, 'pos': 0.0, 'compound': -0.5562}
# result: Negative
#
# Feedback: Del Taco is pretty nasty and should be avoided if possible.
# Scores: {'neg': 0.349, 'neu': 0.465, 'pos': 0.186, 'compound': -0.4215}
# result: Negative
#
# Feedback: It's NOT hard to make a decent hamburger.
# Scores: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.0762}
# ressult: Positive
#
# Feedback: But I don't like it.
# Scores: {'neg': 0.47, 'neu': 0.53, 'pos': 0.0, 'compound': -0.395}
# result: Negative
#
# Feedback: Hell no will I go back
# Scores: {'neg': 0.694, 'neu': 0.306, 'pos': 0.0, 'compound': -0.7783}
# result: Negative
#
# Feedback: We've have gotten a much better service from the pizza place next door than the services we received from this restaurant.
# Scores: {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.4404}
# ressult: Positive
#
# Feedback: I don't know what the big deal is about this place, but I won't be back "ya'all".
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I immediately said I wanted to talk to the manager but I did not want to talk to the guy who was doing shots of fireball behind the bar.
# Scores: {'neg': 0.051, 'neu': 0.949, 'pos': 0.0, 'compound': -0.0857}
# result: Negative
#
# Feedback: The ambiance isn't much better.
# Scores: {'neg': 0.376, 'neu': 0.624, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: Unfortunately, it only set us up for disapppointment with our entrees.
# Scores: {'neg': 0.194, 'neu': 0.806, 'pos': 0.0, 'compound': -0.34}
# result: Negative
#
# Feedback: The food wasn't good.
# Scores: {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412}
# result: Negative
#
# Feedback: Your servers suck, wait, correction, our server Heimer sucked.
# Scores: {'neg': 0.457, 'neu': 0.543, 'pos': 0.0, 'compound': -0.7096}
# result: Negative
#
# Feedback: What happened next was pretty....off putting.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: too bad cause I know it's family owned, I really wanted to like this place.
# Scores: {'neg': 0.203, 'neu': 0.637, 'pos': 0.16, 'compound': -0.1868}
# result: Negative
#
# Feedback: Overpriced for what you are getting.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I vomited in the bathroom mid lunch.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: I kept looking at the time and it had soon become 35 minutes, yet still no food.
# Scores: {'neg': 0.128, 'neu': 0.872, 'pos': 0.0, 'compound': -0.296}
# result: Negative
#
# Feedback: I have been to very few places to eat that under no circumstances would I ever return to, and this tops the list.
# Scores: {'neg': 0.088, 'neu': 0.758, 'pos': 0.155, 'compound': 0.397}
# ressult: Positive
#
# Feedback: We started with the tuna sashimi which was brownish in color and obviously wasn't fresh.
# Scores: {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.2411}
# result: Negative
#
# Feedback: Food was below average.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: It sure does beat the nachos at the movies but I would expect a little bit more coming from a restaurant.
# Scores: {'neg': 0.0, 'neu': 0.912, 'pos': 0.088, 'compound': 0.1655}
# ressult: Positive
#
# Feedback: All in all, Ha Long Bay was a bit of a flop.
# Scores: {'neg': 0.187, 'neu': 0.625, 'pos': 0.187, 'compound': 0.0}
# result: Neutral
#
# Feedback: The problem I have is that they charge $11.99 for a sandwich that is no bigger than a Subway sub (which offers better and more amount of vegetables).
# Scores: {'neg': 0.164, 'neu': 0.738, 'pos': 0.097, 'compound': -0.25}
# result: Negative
#
# Feedback: Shrimp- When I unwrapped it (I live only 1/2 a mile from Brushfire) it was literally ice cold.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: It lacked flavor, seemed undercooked, and dry.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: It really is impressive that the place hasn't closed down.
# Scores: {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.5542}
# ressult: Positive
#
# Feedback: I would avoid this place if you are staying in the Mirage.
# Scores: {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
# result: Negative
#
# Feedback: The refried beans that came with my meal were dried out and crusty and the food was bland.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Spend your money and time some place else.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: A lady at the table next to us found a live green caterpillar In her salad.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: the presentation of the food was awful.
# Scores: {'neg': 0.333, 'neu': 0.667, 'pos': 0.0, 'compound': -0.4588}
# result: Negative
#
# Feedback: I can't tell you how disappointed I was.
# Scores: {'neg': 0.383, 'neu': 0.617, 'pos': 0.0, 'compound': -0.4767}
# result: Negative
#
# Feedback: I think food should have flavor and texture and both were lacking.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Appetite instantly gone.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Overall I was not impressed and would not go back.
# Scores: {'neg': 0.242, 'neu': 0.758, 'pos': 0.0, 'compound': -0.3724}
# result: Negative
#
# Feedback: The whole experience was underwhelming, and I think we'll just go to Ninja Sushi next time.
# Scores: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# result: Neutral
#
# Feedback: Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.
# Scores: {'neg': 0.0, 'neu': 0.908, 'pos': 0.092, 'compound': 0.3875}
# ressult: Positive
