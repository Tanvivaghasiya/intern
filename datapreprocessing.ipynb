# %%
import pandas as pd

# %%
a=pd.read_csv('/content/Students_marks.csv')

# %%
a
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
print('it is structured data')
# Out:
# it is structured data

# %% [markdown]
# unstructured data

# %%
from PIL import Image

# %%
a="/content/color-palettes-1-15x10-pastel-bright-monochromatic-discover-20-sets-of-vibrant-color-palettes-5-unique-colors-each-for-stylish-designs-light-dark-vintage-retro-inspirations-new-vector.jpeg"
image=Image.open(a)

# %%
print("Image (Unstructured Data)")
print(f"Format: {image.format}")
print(f"Size: {image.size}")
print(f"Mode: {image.mode}")
# Out:
# Image (Unstructured Data)
# Format: JPEG
# Size: (600, 400)
# Mode: RGB

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download(










)
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
from sklearn.model_selection import train_test_split

# %%
d=pd.read_csv('/content/Students_marks.csv')

# %%
d
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
x=d[['Name',"Gender","Average marks"]]
y=d[['Ranking']]

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=34)

# %%
print('target',y)
print("feature",x)
# Out:
# target      Ranking
# 0       Good
# 1       Okay
# 2       Good
# 3  Very Good
# 4       Okay
# 5  Very Good
# 6       Good
# 7  Very Good
# 8       Good
# 9       Good
# feature       Name Gender  Average marks
# 0  Avneet       F          20.33
# 1      Jay      M          19.33
# 2   Sadaf       F          24.00
# 3  Prakash      M          25.33
# 4   Sarita      F          18.00
# 5  Vasudha      F          82.66
# 6    Ankur      M          23.33
# 7    Laksh      M          26.00
# 8     Aman      M          22.00
# 9    Rajat      M          20.33

# %%
d
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
print(d['Average marks'].mean())
# Out:
# 28.131

# %%
print(d['Average marks'].median())
# Out:
# 22.665

# %%
print(d['Average marks'].mode())
# Out:
# 0    20.33
# Name: Average marks, dtype: float64

# %%
d.isnull().sum()
# Out:
# Roll No.            0
# Name                0
# Gender              0
# Data Structure      0
# Mathematics         0
# Operating System    0
# Average marks       0
# Ranking             0
# dtype: int64

# %%
b=d.dropna()

# %%
data=pd.read_csv('/content/Data.csv')

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#removing rows
data.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.drop_duplicates()          #drop duplicates
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.drop('Age',axis=1)
# Out:
#    Country   Salary Purchased
# 0   France  72000.0       Yes
# 1    Spain  48000.0       Yes
# 2      NaN  54000.0       NaN
# 3    Spain  61000.0        No
# 4  Germany      NaN       Yes
# 5   France  58000.0       Yes
# 6    Spain  52000.0        No
# 7   France  79000.0       Yes
# 8  Germany  83000.0        No
# 9   France  67000.0       Yes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
s=pd.read_csv('/content/scholarship.csv')

# %%
s
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 0                   71.9                      26                1
# 1                   74.6                      38                1
# 2                   75.4                      40                1
# 3                   64.2                       8                1
# 4                   72.3                      17                0
# ..                   ...                     ...              ...
# 995                 88.7                      44                1
# 996                 91.2                      65                1
# 997                 48.9                      34                0
# 998                 86.2                      46                1
# 999                 49.0                      10                1
#
# [1000 rows x 3 columns]

# %%
print(s.columns)
# Out:
# Index(['semester_percentage', 'scholarship_exam_marks', 'got_scholarship'], dtype='object')

# %%
plt.subplot(1,2,1)
sns.distplot(s["semester_percentage"])
plt.subplot(1,2,2)
sns.distplot(s["scholarship_exam_marks"])
plt.show()
# Out:
# <ipython-input-31-c8097cb415fa>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s["semester_percentage"])
# <ipython-input-31-c8097cb415fa>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s["scholarship_exam_marks"])

# %%
print('mean',s['semester_percentage'].mean())
print('min',s['semester_percentage'].min())
print('max',s['semester_percentage'].max())
print('stddev',s['semester_percentage'].std())
# Out:
# mean 69.6124
# min 48.9
# max 91.2
# stddev 6.158978751323897

# %%
print('highest',s['scholarship_exam_marks'].mean()+3*s['scholarship_exam_marks'].std())
print('lowest',s['scholarship_exam_marks'].mean()-3*s['scholarship_exam_marks'].std())
# Out:
# highest 89.61746701676324
# lowest -25.167467016763247

# %%
s[(s['scholarship_exam_marks']>89.61) | (s['scholarship_exam_marks']<-25.16)]
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 9                   77.5                      94                1
# 134                 63.3                      93                0
# 162                 78.0                      90                0
# 324                 66.4                      90                0
# 630                 65.6                      96                1
# 730                 61.4                      90                1
# 846                 69.9                      97                0
# 917                 59.5                     100                0

# %%
#trimming
s[(s['scholarship_exam_marks']<89.61) & (s['scholarship_exam_marks']>-25.16)]
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 0                   71.9                      26                1
# 1                   74.6                      38                1
# 2                   75.4                      40                1
# 3                   64.2                       8                1
# 4                   72.3                      17                0
# ..                   ...                     ...              ...
# 995                 88.7                      44                1
# 996                 91.2                      65                1
# 997                 48.9                      34                0
# 998                 86.2                      46                1
# 999                 49.0                      10                1
#
# [992 rows x 3 columns]

# %% [markdown]
# Iqr

# %%
sns.distplot(s['semester_percentage'])
# Out:
# <ipython-input-36-d02208c3950c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s['semester_percentage'])
# <Axes: xlabel='semester_percentage', ylabel='Density'>

# %%
s['scholarship_exam_marks'].skew()
# Out:
# 0.8356419499466834

# %%
s['scholarship_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: scholarship_exam_marks, dtype: float64

# %%
sns.boxplot(s['scholarship_exam_marks'])
# Out:
# <Axes: ylabel='scholarship_exam_marks'>

# %%
q1=s['scholarship_exam_marks'].quantile(0.25)
q3=s['scholarship_exam_marks'].quantile(0.75)

# %%
q1,q3
# Out:
# (17.0, 44.0)

# %%
IQR=q3-q1

# %%
IQR
# Out:
# 27.0

# %%
min=q1-1.5*IQR
max=q3+1.5*IQR

# %%
#trimming
new=s[(s['scholarship_exam_marks']>min) & (s['scholarship_exam_marks']<max)]

# %%
new
# Out:
#      semester_percentage  scholarship_exam_marks  got_scholarship
# 0                   71.9                      26                1
# 1                   74.6                      38                1
# 2                   75.4                      40                1
# 3                   64.2                       8                1
# 4                   72.3                      17                0
# ..                   ...                     ...              ...
# 995                 88.7                      44                1
# 996                 91.2                      65                1
# 997                 48.9                      34                0
# 998                 86.2                      46                1
# 999                 49.0                      10                1
#
# [985 rows x 3 columns]

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(s["scholarship_exam_marks"])

plt.subplot(2,2,2)
sns.boxplot(s["scholarship_exam_marks"])

plt.subplot(2,2,3)
sns.distplot(new["scholarship_exam_marks"])

plt.subplot(2,2,4)
sns.boxplot(new["scholarship_exam_marks"])

plt.show()
# Out:
# <ipython-input-47-4b47334fb480>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(s["scholarship_exam_marks"])
# <ipython-input-47-4b47334fb480>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new["scholarship_exam_marks"])

# %%
import numpy as np

# %%
new2=s.copy()
new2['scholarship_exam_marks']=np.where(s['scholarship_exam_marks']<max,max, np.where(s['scholarship_exam_marks']>min,min,s['scholarship_exam_marks']))

# %%
new2.shape
# Out:
# (1000, 3)

# %%
new2['scholarship_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       82.880000
# std        13.134234
# min       -23.500000
# 25%        84.500000
# 50%        84.500000
# 75%        84.500000
# max        84.500000
# Name: scholarship_exam_marks, dtype: float64

# %%
p=pd.read_csv('/content/weight-height.csv')

# %%
p.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
sns.distplot(p['Height'])
# Out:
# <ipython-input-54-03a9b426a260>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(p['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.boxplot(p['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
p['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
max=p['Height'].quantile(0.99)
min=p['Weight'].quantile(0.01)

# %%
max
# Out:
# 74.7857900583366

# %%
new_var = p[(p['Height'] > min) & (p['Height'] < max)]

# %%
new_var
# Out:
# Empty DataFrame
# Columns: [Gender, Height, Weight]
# Index: []

# %%
sns.distplot(new_var['Height'])
# Out:
# <ipython-input-96-253fc4846e45>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_var['Height'])
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# <Axes: xlabel='Height'>

# %%
sns.distplot(new_var['Height'])
# Out:
# <ipython-input-97-253fc4846e45>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_var['Height'])
# /usr/local/lib/python3.11/dist-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# /usr/local/lib/python3.11/dist-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.11/dist-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# <Axes: xlabel='Height'>
